# %%
import pygame
import sys

BLACK = pygame.Color(0, 0, 0)
WHITE = pygame.Color(255, 255, 255)
RED = pygame.Color(255, 0, 0)

WIDTH, HEIGHT = 600, 300

SQUARE_WIDTH, SQUARE_HEIGHT = 20, 20

WALL_WIDTH, WALL_HEIGHT = 20, 20

pygame.init()

screen = pygame.display.set_mode((WIDTH, HEIGHT))

clock = pygame.time.Clock()

square = pygame.Rect(WIDTH // 2, HEIGHT // 2, SQUARE_WIDTH, SQUARE_HEIGHT)

velocity = 0.1

destiny = 0, 0

pos_x = pos_y = 0

a = b = x1 = x2 = y1 = y2 = 0

font = pygame.font.Font('freesansbold.ttf', 12)

levels = [
    "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWW",
    "W             WW             W",
    "W    WWWWW    WW             W",
    "W             WW             W",
    "W    WWWWW    WW             W",
    "W             WW             W",
    "W                            W",
    "W                            W",
    "W                            W",
    "W             WW             W",
    "W             WW             W",
    "W                            W",
    "W                            W",
    "W                            W",
    "WWWWWWWWWWWWWWWWWWWWWWWWWWWWWW"
]

left = 0
top = 0

walls = []

for row in levels:
    for col in row:
        if col == 'W':
            wall = pygame.Rect(left, top, WALL_WIDTH, WALL_HEIGHT)
            walls.append(wall)
        left += WALL_WIDTH
    top += WALL_HEIGHT
    if left >= WIDTH:
        left = 0

while True:
    
    dt = clock.tick(60)
    
    events = pygame.event.get()
    
    for event in events:
        if event.type == 5:
            destiny = event.pos
            
        if event.type == pygame.KEYUP:
            if event.key == pygame.K_SPACE:
                square.centerx = WIDTH // 2
                square.centery = HEIGHT // 2
                destiny = 0, 0
                continue
            
    screen.fill(BLACK)        
    
    if (destiny[0] != 0 or destiny[1] != 0):
        x1 = square.centerx
        y1 = square.centery
        x2 = destiny[0]
        y2 = destiny[1]
        
        pygame.draw.line(screen, RED, (x1, y1), (x2, y2), 1)
        
        try:
            a = b = 0
            
            if ((x2 - x1) != 0):
                a = (y2 - y1) / (x2 - x1)
                b = ((y1 * x2) - (y2 * x1)) / (x2 - x1)
                
                x = square.centerx
                y = (a * x) + b
            else:
                print('divisao por 0', x2, x1)
                print('y2:', y2, 'y1:', y1)
                destiny = x2, y2
                print('destiny', destiny)
                #continue
                
                
        except Exception as e:
            print('except', e)
            pygame.quit()
            sys.exit()

            
        
        
        
        pos_x = velocity * dt
        if (destiny[0] < x):
            pos_x = -pos_x
        if (destiny[0] == x):
            pos_x = 0

        pos_y = velocity * dt
        if (destiny[1] < y):
            pos_y = -pos_y
        if (destiny[1] == y):
            pos_y = 0
            
            
        #verifica se deve andar
        if (pos_x != 0 or pos_x != x2):
            square.move_ip(pos_x, 0)
            
        if (pos_y != 0 or pos_x != y2):
            square.move_ip(0, pos_y)
            
        for wall in walls:
            if square.colliderect(wall):
                if pos_x > 0:
                    square.right = wall.left

                if pos_x < 0:
                    square.left = wall.right

                if pos_y > 0:
                    square.bottom = wall.top

                if pos_y < 0:
                    square.top = wall.bottom
            
        
            
        #verifica se chegou
        if (square.centerx == destiny[0] and square.centery == destiny[1]):
            print('chegou')
            destiny = 0, 0
            
    for wall in walls:
        pygame.draw.rect(screen, WHITE, wall)

    str_pos_square = 'square x=' + str(square.centerx) + ', y=' + str(square.centery)
    text_square = font.render(str_pos_square, True, WHITE)
    text_rect_square = text_square.get_rect()
    text_rect_square.center = (WIDTH // 2, HEIGHT - 60)
    
    screen.blit(text_square, text_rect_square)
    
    str_destiny = 'destiny x=' + str(destiny[0]) + ', y=' + str(destiny[1])
    text_destiny = font.render(str_destiny, True, WHITE)
    text_rect_destiny = text_destiny.get_rect()
    text_rect_destiny.center = (WIDTH // 2, HEIGHT - 40)
    
    screen.blit(text_destiny, text_rect_destiny)
    
    pygame.draw.rect(screen, RED, square)
    
    pygame.display.flip()
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# divisao por 0 279 279
# y2: 145 y1: 161
# destiny (279, 145)
# divisao por 0 279 279
# y2: 145 y1: 159
# destiny (279, 145)
# divisao por 0 279 279
# y2: 145 y1: 157
# destiny (279, 145)
# divisao por 0 279 279
# y2: 145 y1: 155
# destiny (279, 145)
# divisao por 0 279 279
# y2: 145 y1: 153
# destiny (279, 145)
# divisao por 0 279 279
# y2: 145 y1: 151
# destiny (279, 145)
# divisao por 0 279 279
# y2: 145 y1: 149
# destiny (279, 145)
# divisao por 0 279 279
# y2: 145 y1: 147
# destiny (279, 145)
# chegou
# divisao por 0 409 409
# y2: 212 y1: 133
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 135
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 137
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 139
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 141
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 143
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 145
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 147
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 149
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 151
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 153
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 155
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 157
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 159
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 161
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 163
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 165
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 167
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 169
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 171
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 173
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 175
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 177
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 179
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 181
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 183
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 185
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 187
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 189
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 191
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 193
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 195
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 197
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 199
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 201
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 203
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 205
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 207
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 209
# destiny (409, 212)
# divisao por 0 409 409
# y2: 212 y1: 211
# destiny (409, 212)
# chegou
# divisao por 0 437 437
# y2: 153 y1: 184
# destiny (437, 153)
# divisao por 0 437 437
# y2: 153 y1: 182
# destiny (437, 153)
# divisao por 0 437 437
# y2: 153 y1: 180
# destiny (437, 153)
# divisao por 0 437 437
# y2: 153 y1: 178
# destiny (437, 153)
# divisao por 0 437 437
# y2: 153 y1: 176
# destiny (437, 153)
# divisao por 0 437 437
# y2: 153 y1: 174
# destiny (437, 153)
# divisao por 0 437 437
# y2: 153 y1: 172
# destiny (437, 153)
# divisao por 0 437 437
# y2: 153 y1: 170
# destiny (437, 153)
# divisao por 0 437 437
# y2: 153 y1: 168
# destiny (437, 153)
# divisao por 0 437 437
# y2: 153 y1: 166
# destiny (437, 153)
# divisao por 0 437 437
# y2: 153 y1: 164
# destiny (437, 153)
# divisao por 0 414 414
# y2: 128 y1: 139
# destiny (414, 128)
# divisao por 0 414 414
# y2: 128 y1: 137
# destiny (414, 128)
# divisao por 0 414 414
# y2: 128 y1: 135
# destiny (414, 128)
# divisao por 0 414 414
# y2: 128 y1: 133
# destiny (414, 128)
# divisao por 0 414 414
# y2: 128 y1: 131
# destiny (414, 128)
# divisao por 0 155 155
# y2: 243 y1: 194
# destiny (155, 243)
# divisao por 0 155 155
# y2: 243 y1: 196
# destiny (155, 243)
# divisao por 0 155 155
# y2: 243 y1: 198
# destiny (155, 243)
# divisao por 0 155 155
# y2: 243 y1: 200
# destiny (155, 243)
# divisao por 0 155 155
# y2: 243 y1: 202
# destiny (155, 243)
# divisao por 0 155 155
# y2: 243 y1: 204
# destiny (155, 243)
# divisao por 0 155 155
# y2: 243 y1: 206
# destiny (155, 243)
# divisao por 0 155 155
# y2: 243 y1: 208
# destiny (155, 243)
# divisao por 0 155 155
# y2: 243 y1: 210
# destiny (155, 243)
# divisao por 0 155 155
# y2: 243 y1: 212
# destiny (155, 243)
# chegou
# divisao por 0 230 230
# y2: 147 y1: 191
# destiny (230, 147)
# divisao por 0 230 230
# y2: 147 y1: 189
# destiny (230, 147)
# divisao por 0 231 231
# y2: 65 y1: 186
# destiny (231, 65)
# divisao por 0 231 231
# y2: 65 y1: 184
# destiny (231, 65)
# divisao por 0 231 231
# y2: 65 y1: 182
# destiny (231, 65)
# divisao por 0 231 231
# y2: 65 y1: 180
# destiny (231, 65)
# divisao por 0 231 231
# y2: 65 y1: 178
# destiny (231, 65)
# divisao por 0 231 231
# y2: 65 y1: 176
# destiny (231, 65)
# divisao por 0 231 231
# y2: 65 y1: 174
# destiny (231, 65)
# divisao por 0 231 231
# y2: 65 y1: 172
# destiny (231, 65)
# divisao por 0 229 229
# y2: 36 y1: 168
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 166
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 164
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 162
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 160
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 158
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 156
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 154
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 152
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 150
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 148
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 146
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 144
# destiny (229, 36)
# divisao por 0 229 229
# y2: 36 y1: 142
# destiny (229, 36)
# divisao por 0 236 236
# y2: 16 y1: 133
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 131
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 129
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 127
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 125
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 123
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 121
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 119
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 117
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 115
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 113
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 111
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 109
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 107
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 105
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 103
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 101
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 99
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 97
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 95
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 93
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 91
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 89
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 87
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 85
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 83
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 81
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 79
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 77
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 75
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 73
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 71
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 69
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 67
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 65
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 63
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 61
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 59
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 57
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 55
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 53
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 51
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 49
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 47
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 45
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 43
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 41
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 39
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 37
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 35
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 33
# destiny (236, 16)
# divisao por 0 236 236
# y2: 16 y1: 31
# destiny (236, 16)
# divisao por 0 245 245
# y2: 74 y1: 98
# destiny (245, 74)
# divisao por 0 245 245
# y2: 74 y1: 96
# destiny (245, 74)
# divisao por 0 245 245
# y2: 74 y1: 94
# destiny (245, 74)
# divisao por 0 245 245
# y2: 74 y1: 92
# destiny (245, 74)
# divisao por 0 245 245
# y2: 74 y1: 90
# destiny (245, 74)
# divisao por 0 210 210
# y2: 68 y1: 110
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 109
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 108
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 107
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 106
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 105
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 104
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 103
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 102
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 101
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 100
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 99
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 98
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 97
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 96
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 95
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 94
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 93
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 92
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 91
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 90
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 89
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 88
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 87
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 86
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 85
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 84
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 83
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 82
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 81
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 80
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 79
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 78
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 77
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 76
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 75
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 74
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 73
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 72
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 71
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 70
# destiny (210, 68)
# divisao por 0 210 210
# y2: 68 y1: 69
# destiny (210, 68)
# chegou
# divisao por 0 222 222
# y2: 72 y1: 42
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 44
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 46
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 48
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 50
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 52
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 54
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 56
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 58
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 60
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 62
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 64
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 66
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 68
# destiny (222, 72)
# divisao por 0 222 222
# y2: 72 y1: 70
# destiny (222, 72)
# chegou
# divisao por 0 215 215
# y2: 64 y1: 35
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 37
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 39
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 41
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 43
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 45
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 47
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 49
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 51
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 53
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 55
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 57
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 59
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 61
# destiny (215, 64)
# divisao por 0 215 215
# y2: 64 y1: 63
# destiny (215, 64)
# chegou
# chegou
# chegou
# divisao por 0 85 85
# y2: 72 y1: 105
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 103
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 101
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 99
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 97
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 95
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 93
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 91
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 89
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 87
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 85
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 83
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 81
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 79
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 77
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 75
# destiny (85, 72)
# divisao por 0 85 85
# y2: 72 y1: 73
# destiny (85, 72)
# chegou
# chegou
# chegou

# %%
p.sumX(3)

# %%
p.printXY()
# Out:
# 3 0

# %%
p.sumY(5)

# %%
p.printXY()
# Out:
# 3 5

# %%
p = Player()
# Out:
# <class 'object'>
# aqui
# <__main__.Player object at 0x7f624414c748>
# 0 0

# %%
p.printXY()
# Out:
# 0 0

# %%
'square x=' + '1' + ', y=' + '2'
# Out:
# 'square x=1, y=2'
